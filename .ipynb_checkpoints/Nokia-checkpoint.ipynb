# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
symbol = "NOK"

# %%
df  = yf.download(tickers = symbol)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1994-07-01  1.289063  1.316406  1.289063  1.316406   0.656262  29958400
# 1994-07-05  1.359375  1.367188  1.347656  1.367188   0.681578  10691200
# 1994-07-06  1.367188  1.414063  1.367188  1.414063   0.704946   7408000
# 1994-07-07  1.410156  1.433594  1.406250  1.433594   0.714683   9747200
# 1994-07-08  1.429688  1.445313  1.417969  1.441406   0.718578   4467200
# ...              ...       ...       ...       ...        ...       ...
# 2023-04-17  4.860000  4.870000  4.810000  4.850000   4.850000  16201200
# 2023-04-18  4.820000  4.830000  4.590000  4.660000   4.660000  29728400
# 2023-04-19  4.670000  4.670000  4.550000  4.620000   4.620000  32830000
# 2023-04-20  4.280000  4.300000  4.130000  4.200000   4.200000  58372900
# 2023-04-21  4.180000  4.230000  4.160000  4.220000   4.220000  29375500
#
# [7253 rows x 6 columns]

# %%
df.index
# Out:
# DatetimeIndex(['1994-07-01', '1994-07-05', '1994-07-06', '1994-07-07',
#                '1994-07-08', '1994-07-11', '1994-07-12', '1994-07-13',
#                '1994-07-14', '1994-07-15',
#                ...
#                '2023-04-10', '2023-04-11', '2023-04-12', '2023-04-13',
#                '2023-04-14', '2023-04-17', '2023-04-18', '2023-04-19',
#                '2023-04-20', '2023-04-21'],
#               dtype='datetime64[ns]', name='Date', length=7253, freq=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7253 entries, 1994-07-01 to 2023-04-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       7253 non-null   float64
#  1   High       7253 non-null   float64
#  2   Low        7253 non-null   float64
#  3   Close      7253 non-null   float64
#  4   Adj Close  7253 non-null   float64
#  5   Volume     7253 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 396.6 KB

# %%
# Price chart

df.Close.plot(figsize = (12,8), fontsize =12)
plt.ylabel("Price (USD)")
plt.title("Nokia price chart", fontsize = 15)
plt.show()

# %%
#Volume chart
df.loc("2023-4", "Volume").plot(figsize = (12,8) kind= "bar")
plt.ylabel("Volume (shares)")
plt.title("Nokia trading volume (daily)", fontsize=15)
plt.show()
